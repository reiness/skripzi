# %% [markdown]
# # Stratified Random Sampling

# %%
import os
import shutil
import random

# Root dataset directory
root_dir = 'Z:/ExDark'  # Root folder of the dataset
output_dir = 'Z:/ExDark/data'  # Root folder for split datasets

train_dir = os.path.join(output_dir, 'train')
val_dir = os.path.join(output_dir, 'val')

# Supported image formats
image_extensions = ['.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG']  # Add more formats if needed

# Make directories for train and val
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# Train-val split ratio
train_ratio = 0.8
val_ratio = 0.2

# Get all class folders excluding 'data' folder
class_folders = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d)) and d != 'data']

# Function to check if a file is an image based on the extension
def is_image_file(filename):
    return any(filename.lower().endswith(ext) for ext in image_extensions)

# Iterate over all detected class folders
for class_name in class_folders:
    class_image_dir = os.path.join(root_dir, class_name)

    # Get all files in the folder and filter only image files
    class_files = [f for f in os.listdir(class_image_dir) if is_image_file(f)]
    
    # Create class subdirectories for train and val
    class_train_dir = os.path.join(train_dir, class_name)
    class_val_dir = os.path.join(val_dir, class_name)
    os.makedirs(class_train_dir, exist_ok=True)
    os.makedirs(class_val_dir, exist_ok=True)

    # Shuffle files for random split
    random.shuffle(class_files)
    
    # Calculate train/val split
    train_count = int(len(class_files) * train_ratio)
    
    # Split into train and val sets
    train_files = class_files[:train_count]
    val_files = class_files[train_count:]

    # Copy files to train folder
    for file_name in train_files:
        base_name, ext = os.path.splitext(file_name)  # Split base name and extension
        img_src_path = os.path.join(class_image_dir, file_name)
        
        # Copy image file
        img_dst_path = os.path.join(class_train_dir, file_name)
        shutil.copy(img_src_path, img_dst_path)
        
        # Copy corresponding annotation files for each image extension
        for img_ext in image_extensions:
            if ext.lower() == img_ext:
                txt_src_path = os.path.join(class_image_dir, f"{base_name}{img_ext}.txt")
                txt_dst_path = os.path.join(class_train_dir, f"{base_name}{img_ext}.txt")
                if os.path.exists(txt_src_path):
                    shutil.copy(txt_src_path, txt_dst_path)
                else:
                    print(f"Annotation file not found: {txt_src_path}")

    # Copy files to val folder
    for file_name in val_files:
        base_name, ext = os.path.splitext(file_name)
        img_src_path = os.path.join(class_image_dir, file_name)
        
        # Copy image file
        img_dst_path = os.path.join(class_val_dir, file_name)
        shutil.copy(img_src_path, img_dst_path)
        
        # Copy corresponding annotation files for each image extension
        for img_ext in image_extensions:
            if ext.lower() == img_ext:
                txt_src_path = os.path.join(class_image_dir, f"{base_name}{img_ext}.txt")
                txt_dst_path = os.path.join(class_val_dir, f"{base_name}{img_ext}.txt")
                if os.path.exists(txt_src_path):
                    shutil.copy(txt_src_path, txt_dst_path)
                else:
                    print(f"Annotation file not found: {txt_src_path}")

    print(f"Class '{class_name}' split: {train_count} images in train, {len(val_files)} in val.")
# Out:
# Class 'Bicycle' split: 521 images in train, 131 in val.
# Class 'Boat' split: 543 images in train, 136 in val.
# Class 'Bottle' split: 437 images in train, 110 in val.
# Class 'Bus' split: 421 images in train, 106 in val.
# Class 'Car' split: 510 images in train, 128 in val.
# Class 'Cat' split: 588 images in train, 147 in val.
# Class 'Chair' split: 518 images in train, 130 in val.
# Class 'Cup' split: 415 images in train, 104 in val.
# Class 'Dog' split: 640 images in train, 161 in val.
# Class 'Motorbike' split: 402 images in train, 101 in val.
# Class 'People' split: 487 images in train, 122 in val.
# Class 'Table' split: 404 images in train, 101 in val.

# %% [markdown]
# # Conversion

# %%
import os
from PIL import Image  # Library to get image size

# Class name to ID mapping (example, modify as needed for ExDark)
class_name_to_id = {
    "Bicycle": 0,
    "Boat": 1,
    "Bottle": 2,
    "Bus": 3,
    "Car": 4,
    "Cat": 5,
    "Chair": 6,
    "Cup": 7,
    "Dog": 8,
    "Motorbike": 9,
    "People": 10,
    "Table": 11
}

# Function to convert the annotations
def convert_annotation(input_path, output_path, image_width, image_height):
    with open(input_path, 'r') as file:
        lines = file.readlines()
    
    with open(output_path, 'w') as output_file:
        for line in lines:
            if line.startswith('%') or line.strip() == "":
                continue  # Skip header or empty lines

            parts = line.split()
            class_name = parts[0]  # Object class name
            l = float(parts[1])  # Left (x)
            t = float(parts[2])  # Top (y)
            w = float(parts[3])  # Width
            h = float(parts[4])  # Height

            # Convert class name to class ID
            class_id = class_name_to_id.get(class_name, -1)
            if class_id == -1:
                print(f"Warning: Class '{class_name}' not found in mapping.")
                continue

            # YOLO format requires center_x, center_y, width, height normalized
            x_center = (l + w / 2) / image_width
            y_center = (t + h / 2) / image_height
            width = w / image_width
            height = h / image_height

            # Write to the new YOLO format file
            output_file.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

# Directory paths
root_dir = 'Z:/ExDark/data'  # Base directory containing 'train' and 'val'
folders_to_process = ['train', 'val']  # Folders to process

# Supported image formats
image_extensions = ['.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG']

# Helper function to find the corresponding image file
def find_image_file(base_filename, directory):
    # Ensure base_filename doesn't contain an extension
    base_filename_without_ext = os.path.splitext(base_filename)[0]
    
    for ext in image_extensions:
        image_path = os.path.join(directory, base_filename_without_ext + ext)
        if os.path.isfile(image_path):  # Check if file exists
            print(f"Found image file: {image_path}")  # Debug print
            return image_path
    print(f"Image file not found for base filename '{base_filename_without_ext}'")  # Debug print
    return None

# Loop through 'train' and 'val' directories
for folder in folders_to_process:
    folder_path = os.path.join(root_dir, folder)
    print(f"Processing folder: {folder_path}")  # Debug print

    for class_name in os.listdir(folder_path):
        class_dir = os.path.join(folder_path, class_name)
        if not os.path.isdir(class_dir):
            print(f"Skipping non-directory: {class_dir}")  # Debug print
            continue  # Skip if it's not a directory

        # Process each file in the class folder
        for annotation_file in os.listdir(class_dir):
            if annotation_file.endswith('.txt'):
                annotation_path = os.path.join(class_dir, annotation_file)

                # The base image filename without the '.txt'
                base_filename = annotation_file.replace('.txt', '')
                print(f"Processing annotation file: {annotation_path}")  # Debug print

                # Find the image with any supported format
                image_path = find_image_file(base_filename, class_dir)

                if image_path is None:
                    print(f"Warning: Image file for '{base_filename}' not found.")
                    continue
                
                # Get the resolution (width, height) of the image
                try:
                    with Image.open(image_path) as img:
                        image_width, image_height = img.size
                except Exception as e:
                    print(f"Error opening image file {image_path}: {e}")
                    continue

                # Convert and overwrite the existing annotation file in YOLO format
                convert_annotation(annotation_path, annotation_path, image_width, image_height)
                print(f"Converted: {annotation_path} with resolution {image_width}x{image_height}")

print("Conversion completed!")
# Out:
# Processing folder: Z:/ExDark/data\train
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00001.png.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00001.png
# Converted: Z:/ExDark/data\train\Bicycle\2015_00001.png.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00002.png.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00002.png
# Converted: Z:/ExDark/data\train\Bicycle\2015_00002.png.txt with resolution 500x341
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00003.png.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00003.png
# Converted: Z:/ExDark/data\train\Bicycle\2015_00003.png.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00004.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00004.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00004.jpg.txt with resolution 640x360
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00005.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00005.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00005.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00006.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00006.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00006.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00008.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00008.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00008.jpg.txt with resolution 333x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00009.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00009.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00009.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00010.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00010.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00010.jpg.txt with resolution 864x576
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00012.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00012.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00012.jpg.txt with resolution 1024x768
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00014.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00014.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00014.jpg.txt with resolution 767x536
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00015.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00015.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00015.jpg.txt with resolution 800x800
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00016.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00016.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00016.jpg.txt with resolution 640x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00017.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00017.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00017.jpg.txt with resolution 338x505
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00019.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00019.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00019.jpg.txt with resolution 506x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00020.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00020.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00020.jpg.txt with resolution 640x363
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00021.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00021.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00021.jpg.txt with resolution 508x337
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00022.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00022.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00022.jpg.txt with resolution 332x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00024.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00024.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00024.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00025.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00025.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00025.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00027.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00027.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00027.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00028.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00028.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00028.jpg.txt with resolution 640x408
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00029.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00029.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00029.jpg.txt with resolution 530x800
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00031.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00031.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00031.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00032.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00032.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00032.jpg.txt with resolution 640x428
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00033.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00033.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00033.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00034.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00034.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00034.jpg.txt with resolution 306x306
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00035.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00035.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00035.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00037.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00037.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00037.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00038.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00038.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00038.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00040.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00040.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00040.jpg.txt with resolution 1600x1063
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00042.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00042.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00042.jpg.txt with resolution 640x424
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00044.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00044.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00044.jpg.txt with resolution 414x414
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00045.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00045.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00045.jpg.txt with resolution 414x414
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00046.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00046.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00046.jpg.txt with resolution 382x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00047.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00047.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00047.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00049.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00049.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00049.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00050.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00050.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00050.jpg.txt with resolution 768x1024
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00051.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00051.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00051.jpg.txt with resolution 478x359
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00052.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00052.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00052.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00054.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00054.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00054.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00055.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00055.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00055.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00056.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00056.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00056.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00057.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00057.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00057.jpg.txt with resolution 506x339
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00058.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00058.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00058.jpg.txt with resolution 414x414
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00059.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00059.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00059.jpg.txt with resolution 638x344
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00060.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00060.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00060.jpg.txt with resolution 607x405
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00062.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00062.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00062.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00063.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00063.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00063.jpg.txt with resolution 338x507
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00064.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00064.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00064.jpg.txt with resolution 360x180
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00065.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00065.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00065.jpg.txt with resolution 1600x1063
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00066.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00066.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00066.jpg.txt with resolution 640x428
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00067.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00067.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00067.jpg.txt with resolution 500x474
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00068.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00068.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00068.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00069.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00069.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00069.jpg.txt with resolution 640x481
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00070.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00070.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00070.jpg.txt with resolution 1596x931
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00072.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00072.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00072.jpg.txt with resolution 490x350
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00074.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00074.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00074.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00075.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00075.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00075.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00077.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00077.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00077.jpg.txt with resolution 1024x768
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00078.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00078.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00078.jpg.txt with resolution 508x337
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00080.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00080.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00080.jpg.txt with resolution 513x334
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00081.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00081.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00081.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00082.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00082.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00082.jpg.txt with resolution 339x506
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00083.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00083.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00083.jpg.txt with resolution 333x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00085.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00085.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00085.jpg.txt with resolution 1600x1067
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00086.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00086.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00086.jpg.txt with resolution 427x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00087.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00087.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00087.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00088.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00088.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00088.jpg.txt with resolution 1024x768
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00089.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00089.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00089.jpg.txt with resolution 640x424
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00090.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00090.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00090.jpg.txt with resolution 412x416
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00091.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00091.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00091.jpg.txt with resolution 413x416
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00093.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00093.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00093.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00094.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00094.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00094.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00095.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00095.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00095.jpg.txt with resolution 1600x1066
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00096.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00096.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00096.jpg.txt with resolution 640x456
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00097.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00097.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00097.jpg.txt with resolution 427x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00098.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00098.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00098.jpg.txt with resolution 1600x1067
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00100.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00100.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00100.jpg.txt with resolution 850x638
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00101.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00101.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00101.jpg.txt with resolution 506x339
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00102.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00102.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00102.jpg.txt with resolution 338x507
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00103.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00103.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00103.jpg.txt with resolution 499x420
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00104.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00104.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00104.jpg.txt with resolution 1024x819
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00106.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00106.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00106.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00107.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00107.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00107.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00110.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00110.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00110.jpg.txt with resolution 1024x768
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00111.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00111.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00111.jpg.txt with resolution 339x506
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00112.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00112.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00112.jpg.txt with resolution 500x430
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00113.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00113.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00113.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00114.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00114.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00114.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00115.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00115.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00115.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00116.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00116.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00116.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00117.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00117.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00117.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00119.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00119.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00119.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00120.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00120.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00120.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00121.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00121.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00121.jpg.txt with resolution 480x357
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00122.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00122.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00122.jpg.txt with resolution 338x507
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00123.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00123.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00123.jpg.txt with resolution 640x424
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00124.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00124.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00124.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00125.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00125.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00125.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00127.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00127.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00127.jpg.txt with resolution 640x407
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00128.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00128.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00128.jpg.txt with resolution 500x342
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00129.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00129.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00129.jpg.txt with resolution 639x407
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00130.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00130.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00130.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00131.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00131.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00131.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00132.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00132.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00132.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00133.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00133.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00133.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00134.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00134.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00134.jpg.txt with resolution 640x512
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00135.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00135.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00135.jpg.txt with resolution 799x924
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00136.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00136.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00136.jpg.txt with resolution 857x639
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00137.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00137.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00137.jpg.txt with resolution 499x341
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00138.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00138.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00138.jpg.txt with resolution 359x478
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00139.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00139.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00139.jpg.txt with resolution 500x331
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00140.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00140.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00140.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00141.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00141.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00141.jpg.txt with resolution 375x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00142.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00142.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00142.jpg.txt with resolution 854x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00143.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00143.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00143.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00144.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00144.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00144.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00145.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00145.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00145.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00146.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00146.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00146.jpg.txt with resolution 500x357
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00147.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00147.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00147.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00148.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00148.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00148.jpg.txt with resolution 2592x1936
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00149.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00149.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00149.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00150.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00150.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00150.jpg.txt with resolution 640x489
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00151.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00151.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00151.jpg.txt with resolution 800x564
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00152.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00152.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00152.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00153.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00153.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00153.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00154.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00154.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00154.jpg.txt with resolution 426x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00155.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00155.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00155.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00158.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00158.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00158.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00159.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00159.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00159.jpg.txt with resolution 600x600
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00160.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00160.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00160.jpg.txt with resolution 602x383
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00161.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00161.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00161.jpg.txt with resolution 525x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00162.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00162.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00162.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00163.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00163.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00163.jpg.txt with resolution 640x287
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00164.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00164.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00164.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00165.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00165.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00165.jpg.txt with resolution 328x471
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00166.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00166.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00166.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00167.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00167.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00167.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00169.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00169.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00169.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00170.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00170.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00170.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00172.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00172.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00172.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00174.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00174.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00174.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00175.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00175.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00175.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00177.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00177.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00177.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00178.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00178.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00178.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00179.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00179.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00179.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00182.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00182.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00182.jpg.txt with resolution 520x398
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00183.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00183.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00183.jpg.txt with resolution 640x458
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00184.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00184.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00184.jpg.txt with resolution 333x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00185.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00185.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00185.jpg.txt with resolution 640x479
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00186.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00186.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00186.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00188.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00188.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00188.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00189.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00189.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00189.jpg.txt with resolution 426x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00190.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00190.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00190.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00191.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00191.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00191.jpg.txt with resolution 640x425
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00192.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00192.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00192.jpg.txt with resolution 333x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00193.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00193.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00193.jpg.txt with resolution 683x1024
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00194.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00194.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00194.jpg.txt with resolution 640x428
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00195.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00195.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00195.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00197.png.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00197.png
# Converted: Z:/ExDark/data\train\Bicycle\2015_00197.png.txt with resolution 620x412
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00198.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00198.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00198.jpg.txt with resolution 683x1024
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00199.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00199.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00199.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00200.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00200.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00200.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00201.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00201.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00201.jpg.txt with resolution 640x434
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00202.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00202.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00202.jpg.txt with resolution 500x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00203.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00203.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00203.jpg.txt with resolution 1024x685
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00204.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00204.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00204.jpg.txt with resolution 1024x685
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00205.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00205.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00205.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00206.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00206.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00206.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00207.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00207.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00207.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00208.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00208.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00208.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00209.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00209.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00209.jpg.txt with resolution 683x1024
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00210.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00210.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00210.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00212.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00212.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00212.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00213.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00213.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00213.jpg.txt with resolution 334x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00214.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00214.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00214.jpg.txt with resolution 334x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00215.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00215.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00215.jpg.txt with resolution 640x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00216.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00216.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00216.jpg.txt with resolution 375x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00218.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00218.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00218.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00219.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00219.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00219.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00220.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00220.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00220.jpg.txt with resolution 640x425
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00223.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00223.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00223.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00224.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00224.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00224.jpg.txt with resolution 338x506
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00225.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00225.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00225.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00226.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00226.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00226.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00227.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00227.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00227.jpg.txt with resolution 521x332
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00228.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00228.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00228.jpg.txt with resolution 500x275
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00231.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00231.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00231.jpg.txt with resolution 640x481
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00233.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00233.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00233.jpg.txt with resolution 489x326
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00234.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00234.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00234.jpg.txt with resolution 1024x672
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00235.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00235.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00235.jpg.txt with resolution 338x507
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00236.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00236.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00236.jpg.txt with resolution 333x513
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00237.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00237.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00237.jpg.txt with resolution 350x490
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00238.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00238.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00238.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00239.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00239.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00239.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00240.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00240.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00240.jpg.txt with resolution 508x337
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00241.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00241.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00241.jpg.txt with resolution 1024x685
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00242.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00242.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00242.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00244.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00244.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00244.jpg.txt with resolution 685x1024
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00245.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00245.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00245.jpg.txt with resolution 1024x685
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00248.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00248.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00248.jpg.txt with resolution 640x429
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00249.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00249.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00249.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00251.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00251.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00251.jpg.txt with resolution 640x380
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00253.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00253.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00253.jpg.txt with resolution 552x311
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00254.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00254.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00254.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00255.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00255.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00255.jpg.txt with resolution 333x500
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00256.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00256.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00256.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00257.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00257.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00257.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00258.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00258.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00258.jpg.txt with resolution 454x377
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00259.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00259.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00259.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00261.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00261.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00261.jpg.txt with resolution 507x338
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00262.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00262.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00262.jpg.txt with resolution 640x399
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00263.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00263.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00263.jpg.txt with resolution 507x337
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00264.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00264.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00264.jpg.txt with resolution 640x360
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00268.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00268.jpg
# Converted: Z:/ExDark/data\train\Bicycle\2015_00268.jpg.txt with resolution 313x543
# Processing annotation file: Z:/ExDark/data\train\Bicycle\2015_00269.jpg.txt
# Found image file: Z:/ExDark/data\train\Bicycle\2015_00269.jpg
# ...
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06956.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06956.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06956.jpg.txt with resolution 1024x663
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06972.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06972.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06972.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06975.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06975.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06975.jpg.txt with resolution 640x453
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06980.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06980.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06980.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06996.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06996.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06996.jpg.txt with resolution 500x472
# Processing annotation file: Z:/ExDark/data\val\Table\2015_06997.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_06997.jpg
# Converted: Z:/ExDark/data\val\Table\2015_06997.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07008.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07008.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07008.jpg.txt with resolution 1024x1024
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07016.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07016.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07016.jpg.txt with resolution 640x426
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07024.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07024.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07024.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07027.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07027.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07027.jpg.txt with resolution 1008x670
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07030.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07030.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07030.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07040.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07040.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07040.jpg.txt with resolution 640x427
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07048.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07048.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07048.jpg.txt with resolution 640x428
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07060.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07060.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07060.jpg.txt with resolution 768x514
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07062.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07062.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07062.jpg.txt with resolution 451x381
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07074.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07074.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07074.jpg.txt with resolution 480x356
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07078.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07078.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07078.jpg.txt with resolution 366x467
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07088.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07088.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07088.jpg.txt with resolution 506x338
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07091.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07091.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07091.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07098.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07098.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07098.jpg.txt with resolution 484x353
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07108.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07108.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07108.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07111.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07111.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07111.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07113.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07113.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07113.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07114.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07114.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07114.jpg.txt with resolution 500x333
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07121.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07121.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07121.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07125.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07125.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07125.jpg.txt with resolution 597x592
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07131.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07131.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07131.jpg.txt with resolution 480x640
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07133.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07133.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07133.jpg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07136.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07136.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07136.jpg.txt with resolution 640x480
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07138.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07138.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07138.jpg.txt with resolution 500x240
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07146.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07146.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07146.jpg.txt with resolution 4320x3240
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07148.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07148.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07148.jpg.txt with resolution 3104x1746
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07149.jpeg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07149.jpeg
# Converted: Z:/ExDark/data\val\Table\2015_07149.jpeg.txt with resolution 375x500
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07160.jpeg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07160.jpeg
# Converted: Z:/ExDark/data\val\Table\2015_07160.jpeg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07167.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07167.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07167.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07169.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07169.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07169.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07173.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07173.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07173.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07175.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07175.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07175.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07185.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07185.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07185.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07188.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07188.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07188.jpg.txt with resolution 2448x3264
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07199.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07199.png
# Converted: Z:/ExDark/data\val\Table\2015_07199.png.txt with resolution 1440x900
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07208.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07208.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07208.jpg.txt with resolution 592x795
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07209.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07209.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07209.jpg.txt with resolution 900x599
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07210.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07210.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07210.jpg.txt with resolution 600x937
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07213.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07213.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07213.jpg.txt with resolution 900x600
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07220.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07220.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07220.jpg.txt with resolution 877x694
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07225.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07225.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07225.jpg.txt with resolution 701x1140
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07232.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07232.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07232.jpg.txt with resolution 1024x683
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07239.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07239.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07239.jpg.txt with resolution 600x450
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07244.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07244.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07244.jpg.txt with resolution 1024x1006
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07248.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07248.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07248.jpg.txt with resolution 900x528
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07250.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07250.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07250.jpg.txt with resolution 259x194
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07252.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07252.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07252.jpg.txt with resolution 900x672
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07253.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07253.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07253.jpg.txt with resolution 600x800
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07274.jpeg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07274.jpeg
# Converted: Z:/ExDark/data\val\Table\2015_07274.jpeg.txt with resolution 500x375
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07282.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07282.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07282.jpg.txt with resolution 600x400
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07285.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07285.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07285.jpg.txt with resolution 600x450
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07286.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07286.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07286.jpg.txt with resolution 600x784
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07293.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07293.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07293.jpg.txt with resolution 857x588
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07297.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07297.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07297.jpg.txt with resolution 774x1032
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07299.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07299.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07299.jpg.txt with resolution 600x854
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07300.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07300.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07300.jpg.txt with resolution 600x800
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07306.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07306.png
# Converted: Z:/ExDark/data\val\Table\2015_07306.png.txt with resolution 597x725
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07307.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07307.png
# Converted: Z:/ExDark/data\val\Table\2015_07307.png.txt with resolution 774x775
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07312.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07312.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07312.jpg.txt with resolution 600x473
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07316.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07316.png
# Converted: Z:/ExDark/data\val\Table\2015_07316.png.txt with resolution 720x404
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07319.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07319.png
# Converted: Z:/ExDark/data\val\Table\2015_07319.png.txt with resolution 1280x532
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07320.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07320.png
# Converted: Z:/ExDark/data\val\Table\2015_07320.png.txt with resolution 1280x534
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07323.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07323.png
# Converted: Z:/ExDark/data\val\Table\2015_07323.png.txt with resolution 1280x528
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07328.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07328.png
# Converted: Z:/ExDark/data\val\Table\2015_07328.png.txt with resolution 1920x1040
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07329.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07329.png
# Converted: Z:/ExDark/data\val\Table\2015_07329.png.txt with resolution 1280x544
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07338.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07338.png
# Converted: Z:/ExDark/data\val\Table\2015_07338.png.txt with resolution 720x404
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07346.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07346.png
# Converted: Z:/ExDark/data\val\Table\2015_07346.png.txt with resolution 1280x720
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07350.png.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07350.png
# Converted: Z:/ExDark/data\val\Table\2015_07350.png.txt with resolution 1280x720
# Processing annotation file: Z:/ExDark/data\val\Table\2015_07354.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2015_07354.jpg
# Converted: Z:/ExDark/data\val\Table\2015_07354.jpg.txt with resolution 1024x768
# Processing annotation file: Z:/ExDark/data\val\Table\2017_07358.jpg.txt
# Found image file: Z:/ExDark/data\val\Table\2017_07358.jpg
# Converted: Z:/ExDark/data\val\Table\2017_07358.jpg.txt with resolution 1024x683
# Conversion completed!

# %% [markdown]
# # Special format remover

# %%
import os

# Define the paths to the data/train and data/val directories
directories = ['data/train', 'data/val']

# Define the image extensions that need to be removed
image_extensions = ['.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG']

def rename_txt_files(directory):
    for foldername, subfolders, filenames in os.walk(directory):
        for filename in filenames:
            if filename.endswith('.txt'):
                # Remove image extension from the filename if present before '.txt'
                new_filename = filename
                for ext in image_extensions:
                    if ext in filename:
                        new_filename = filename.replace(ext, '')
                        break  # Exit loop after finding the first matching extension
                
                # Create the full path for the current and new filenames
                old_file = os.path.join(foldername, filename)
                new_file = os.path.join(foldername, new_filename)
                
                # Rename the file
                os.rename(old_file, new_file)

# Run the renaming process for both the data/train and data/val directories
for directory in directories:
    rename_txt_files(directory)

print("Renaming complete!")
# Out:
# Renaming complete!

# %% [markdown]
# # Boxer

# %%
from PIL import Image, ImageDraw, ImageFont

# Function to parse annotations and draw bounding boxes with labels
def draw_bounding_boxes(image_path, annotations, font_path='arial.ttf', font_size=30):
    # Open an image
    img = Image.open(image_path)
    draw = ImageDraw.Draw(img)

    # Load a TrueType font (you can specify a font path if needed)
    try:
        font = ImageFont.truetype(font_path, font_size)  # Increase font size
    except IOError:
        print(f"Font file '{font_path}' not found. Using default font.")
        font = ImageFont.load_default()

    # Loop through each annotation
    for annotation in annotations:
        # Parse the annotation details
        parts = annotation.split()
        obj_class = parts[0]
        l, t, w, h = map(int, parts[1:5])
        
        # Define the bounding box (left, top, right, bottom)
        bbox = (l, t, l + w, t + h)
        
        # Draw the bounding box on the image with a thicker line (width=5)
        draw.rectangle(bbox, outline="red", width=15)
        
        # Get the size of the label
        text_size = draw.textsize(obj_class, font=font)
        
        # Draw label background
        text_background = [(l, t - text_size[1] - 10), (l + text_size[0], t)]
        draw.rectangle(text_background, fill="red")  # Background for the label
        
        # Draw the label above the box
        draw.text((l, t - text_size[1] - 10), obj_class, fill="white", font=font)

    # Show the image with bounding boxes and labels
    img.show()

# Example annotations from the bbGt format
annotations = [
    "People 1578 1061 391 1146 0 0 0 0 0 0 0",
    "Car 1841 1214 446 412 0 0 0 0 0 0 0",
    "Car 2321 1273 276 136 0 0 0 0 0 0 0"
]

# Image path to be annotated
image_path = 'Z:/ExDark/People/2015_06691.JPG'

# Call the function to draw bounding boxes on the image
draw_bounding_boxes(image_path, annotations, font_size=72)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20488\3157494363.py:30: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_size = draw.textsize(obj_class, font=font)
# C:\Users\User\AppData\Local\Temp\ipykernel_20488\3157494363.py:30: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_size = draw.textsize(obj_class, font=font)
# C:\Users\User\AppData\Local\Temp\ipykernel_20488\3157494363.py:30: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_size = draw.textsize(obj_class, font=font)
